# %%
import datetime
import requests
import pandas as pd
import hopsworks
import great_expectations as ge
import datetime
from pathlib import Path
import util
import json
import re
import os
import warnings
warnings.filterwarnings("ignore")

# %%
import dotenv

dotenv.load_dotenv()

AQI_API_KEY = os.getenv("AQI_API_KEY")
HOPSWORKS_API_KEY = os.getenv("HOPSWORKS_API_KEY")

# %%
csv_file = "data/stockholm-st-eriksgatan-83-air-quality.csv"
util.check_file_path(csv_file)
# Out:
# File successfully found at the path: data/stockholm-st-eriksgatan-83-air-quality.csv

# %%
country = "sweden"
city = "stockholm"
street = "stockholm-st-eriksgatan-83"
aqicn_url="https://api.waqi.info/feed/@10523"

today = datetime.date.today()
latitude, longitude = util.get_city_coordinates(city)
print("Latitude: ", latitude, "Longitude: ", longitude)
# Out:
# Latitude:  59.33 Longitude:  18.07

# %%
project = hopsworks.login()

secrets = util.secrets_api(project.name)
try:
    secrets.create_secret("AQI_API_KEY", AQI_API_KEY)
except hopsworks.RestAPIError:
    AQI_API_KEY = secrets.get_secret("AQI_API_KEY").value
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
#
# Logged in to project, explore it here https://c.app.hopsworks.ai:443/p/1157270
# Connected. Call `.close()` to terminate connection gracefully.

# %%
try:
    aq_today_df = util.get_pm25(aqicn_url, country, city, street, today, AQI_API_KEY)
except hopsworks.RestAPIError:
    print("It looks like the AQI_API_KEY doesn't work for your sensor. Is the API key correct? Is the sensor URL correct?")

aq_today_df.head()
# Out:
#    pm25 country       city                      street       date  \
# 0  21.0  sweden  stockholm  stockholm-st-eriksgatan-83 2024-11-13
#
#                                  url
# 0  https://api.waqi.info/feed/@10523

# %%
# Save the data to a CSV file
df = pd.read_csv(csv_file, parse_dates=["date"], skipinitialspace=True)

df = df[["date", "pm25"]]
df["country"] = country
df["city"] = city
df["street"] = street
df["url"] = aqicn_url
df["pm25"] = df["pm25"].astype("float32")

df.sort_values(by="date", inplace=True)

df["pm25_1_days_before"] = df["pm25"].shift(1)
df["pm25_2_days_before"] = df["pm25"].shift(2)
df["pm25_3_days_before"] = df["pm25"].shift(3)
df["pm25_avg_3_days_before"] = df[["pm25_1_days_before", "pm25_2_days_before", "pm25_3_days_before"]].mean(axis=1)

# Drop rows with missing values
df.dropna(inplace=True)

# Let's check the data
df
# Out:
#            date  pm25 country       city                      street  \
# 2106 2018-04-12  26.0  sweden  stockholm  stockholm-st-eriksgatan-83
# 2107 2018-04-13  33.0  sweden  stockholm  stockholm-st-eriksgatan-83
# 2108 2018-04-14  37.0  sweden  stockholm  stockholm-st-eriksgatan-83
# 2109 2018-04-15  64.0  sweden  stockholm  stockholm-st-eriksgatan-83
# 2110 2018-04-16  70.0  sweden  stockholm  stockholm-st-eriksgatan-83
# ...         ...   ...     ...        ...                         ...
# 7    2024-11-08  19.0  sweden  stockholm  stockholm-st-eriksgatan-83
# 8    2024-11-09  29.0  sweden  stockholm  stockholm-st-eriksgatan-83
# 9    2024-11-10  10.0  sweden  stockholm  stockholm-st-eriksgatan-83
# 10   2024-11-11  20.0  sweden  stockholm  stockholm-st-eriksgatan-83
# 11   2024-11-12   9.0  sweden  stockholm  stockholm-st-eriksgatan-83
#
#                                     url  pm25_1_days_before  \
# 2106  https://api.waqi.info/feed/@10523                23.0
# 2107  https://api.waqi.info/feed/@10523                26.0
# 2108  https://api.waqi.info/feed/@10523                33.0
# 2109  https://api.waqi.info/feed/@10523                37.0
# 2110  https://api.waqi.info/feed/@10523                64.0
# ...                                 ...                 ...
# 7     https://api.waqi.info/feed/@10523                19.0
# 8     https://api.waqi.info/feed/@10523                19.0
# 9     https://api.waqi.info/feed/@10523                29.0
# 10    https://api.waqi.info/feed/@10523                10.0
# 11    https://api.waqi.info/feed/@10523                20.0
#
#       pm25_2_days_before  pm25_3_days_before  pm25_avg_3_days_before
# 2106                14.0                55.0               30.666666
# 2107                23.0                14.0               21.000000
# 2108                26.0                23.0               27.333334
# 2109                33.0                26.0               32.000000
# 2110                37.0                33.0               44.666668
# ...                  ...                 ...                     ...
# 7                   18.0                16.0               17.666666
# 8                   19.0                18.0               18.666666
# 9                   19.0                19.0               22.333334
# 10                  29.0                19.0               19.333334
# 11                  10.0                29.0               19.666666
#
# [2134 rows x 10 columns]

# %%
earliest_date = pd.Series.min(df['date'])
earliest_date = earliest_date.strftime("%Y-%m-%d")
earliest_date

weather_df = util.get_historical_weather(city, earliest_date, str(today), latitude, longitude)
# Out:
# Coordinates 59.29701232910156°N 18.163265228271484°E
# Elevation 18.0 m asl
# Timezone None None
# Timezone difference to GMT+0 0 s

# %%
weather_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2409 entries, 0 to 2408
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         2409 non-null   datetime64[ns]
#  1   temperature_2m_mean          2409 non-null   float32
#  2   precipitation_sum            2409 non-null   float32
#  3   wind_speed_10m_max           2409 non-null   float32
#  4   wind_direction_10m_dominant  2409 non-null   float32
#  5   city                         2409 non-null   object
# dtypes: datetime64[ns](1), float32(4), object(1)
# memory usage: 94.1+ KB

# %%
aq_expectation_suite = ge.core.ExpectationSuite(
    expectation_suite_name="aq_expectation_suite",
)

aq_expectation_suite.add_expectation(
    ge.core.ExpectationConfiguration(
        expectation_type="expect_column_min_to_be_between",
        kwargs={
            "column": "pm25",
            "min_value": -0.1,
            "max_value": 500.0,
            "strict_min": True,
        },
    )
)

weather_expectation_suite = ge.core.ExpectationSuite(
    expectation_suite_name="weather_expectation_suite"
)

def expect_greater_than_zero(col):
    weather_expectation_suite.add_expectation(
        ge.core.ExpectationConfiguration(
            expectation_type="expect_column_min_to_be_between",
            kwargs={
                "column":col,
                "min_value":-0.1,
                "max_value":1000.0,
                "strict_min":True
            }
        )
    )
expect_greater_than_zero("precipitation_sum")
expect_greater_than_zero("wind_speed_10m_max")

# %%
dict_obj = {
    "country": country,
    "city": city,
    "street": street,
    "aqicn_url": aqicn_url,
    "latitude": latitude,
    "longitude": longitude
}

# Convert the dictionary to a JSON string
str_dict = json.dumps(dict_obj)

try:
    secrets.create_secret("SENSOR_LOCATION_JSON", str_dict)
except hopsworks.RestAPIError:
    print("SENSOR_LOCATION_JSON already exists. To update, delete the secret in the UI (https://c.app.hopsworks.ai/account/secrets) and re-run this cell.")
    existing_key = secrets.get_secret("SENSOR_LOCATION_JSON").value
    print(f"{existing_key}")
# Out:
# SENSOR_LOCATION_JSON already exists. To update, delete the secret in the UI (https://c.app.hopsworks.ai/account/secrets) and re-run this cell.
# {"country": "sweden", "city": "stockholm", "street": "stockholm-st-eriksgatan-83", "aqicn_url": "https://api.waqi.info/feed/@10523", "latitude": 59.33, "longitude": 18.07}

# %%
fs = project.get_feature_store()

air_quality_fg = fs.get_or_create_feature_group(
    name='air_quality',
    description='Air Quality characteristics of each day',
    version=1,
    primary_key=['city', 'street', 'date'],
    event_time="date",
    expectation_suite=aq_expectation_suite
)

air_quality_fg.insert(df)

air_quality_fg.update_feature_description("date", "Date of measurement of air quality")
air_quality_fg.update_feature_description("country", "Country where the air quality was measured (sometimes a city in acqcn.org)")
air_quality_fg.update_feature_description("city", "City where the air quality was measured")
air_quality_fg.update_feature_description("street", "Street in the city where the air quality was measured")
air_quality_fg.update_feature_description("pm25", "Particles less than 2.5 micrometers in diameter (fine particles) pose health risk")
air_quality_fg.update_feature_description("pm25_1_days_before", "PM2.5 value 1 day before")
air_quality_fg.update_feature_description("pm25_2_days_before", "PM2.5 value 2 days before")
air_quality_fg.update_feature_description("pm25_3_days_before", "PM2.5 value 3 days before")
air_quality_fg.update_feature_description("pm25_avg_3_days_before", "Average PM2.5 value for the last 3 days")

# Get or create feature group 
weather_fg = fs.get_or_create_feature_group(
    name='weather',
    description='Weather characteristics of each day',
    version=1,
    primary_key=['city', 'date'],
    event_time="date",
    expectation_suite=weather_expectation_suite
) 


# Insert data
weather_fg.insert(weather_df)

weather_fg.update_feature_description("date", "Date of measurement of weather")
weather_fg.update_feature_description("city", "City where weather is measured/forecast for")
weather_fg.update_feature_description("temperature_2m_mean", "Temperature in Celsius")
weather_fg.update_feature_description("precipitation_sum", "Precipitation (rain/snow) in mm")
weather_fg.update_feature_description("wind_speed_10m_max", "Wind speed at 10m abouve ground")
weather_fg.update_feature_description("wind_direction_10m_dominant", "Dominant Wind direction over the dayd")
# Out:
# 2024-11-13 14:10:44,695 WARNING: using legacy validation callback
# Connected. Call `.close()` to terminate connection gracefully.
# ---------------------------------------------------------------------------
# FeatureStoreException                     Traceback (most recent call last)
# Cell In[14], line 12
#       1 fs = project.get_feature_store()
#       3 air_quality_fg = fs.get_or_create_feature_group(
#       4     name='air_quality',
#       5     description='Air Quality characteristics of each day',
#    (...)
#       9     expectation_suite=aq_expectation_suite
#      10 )
# ---> 12 air_quality_fg.insert(df)
#      14 air_quality_fg.update_feature_description("date", "Date of measurement of air quality")
#      15 air_quality_fg.update_feature_description("country", "Country where the air quality was measured (sometimes a city in acqcn.org)")
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/hsfs/feature_group.py:2528, in FeatureGroup.insert(self, features, overwrite, operation, storage, write_options, validation_options, save_code, wait)
#    2525 if "wait_for_job" not in write_options:
#    2526     write_options["wait_for_job"] = wait
# -> 2528 job, ge_report = self._feature_group_engine.insert(
#    2529     self,
#    2530     feature_dataframe=feature_dataframe,
#    2531     overwrite=overwrite,
#    2532     operation=operation,
#    2533     storage=storage.lower() if storage is not None else None,
#    2534     write_options=write_options,
#    2535     validation_options={"save_report": True, **validation_options},
#    2536 )
#    2537 if save_code and (
#    2538     ge_report is None or ge_report.ingestion_result == "INGESTED"
#    2539 ):
#    2540     self._code_engine.save_code(self)
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/hsfs/core/feature_group_engine.py:96, in FeatureGroupEngine.insert(self, feature_group, feature_dataframe, overwrite, operation, storage, write_options, validation_options)
#      91     self.save_feature_group_metadata(
#      92         feature_group, dataframe_features, write_options
#      93     )
#      94 else:
#      95     # else, just verify that feature group schema matches user-provided dataframe
# ---> 96     self._verify_schema_compatibility(
#      97         feature_group.features, dataframe_features
#      98     )
#     100 # ge validation on python and non stream feature groups on spark
#     101 ge_report = feature_group._great_expectation_engine.validate(
#     102     feature_group=feature_group,
#     103     dataframe=feature_dataframe,
#    (...)
#     106     ge_type=False,
#     107 )
#
# File ~/.pyenv/versions/3.12.2/lib/python3.12/site-packages/hsfs/core/feature_group_base_engine.py:155, in FeatureGroupBaseEngine._verify_schema_compatibility(self, feature_group_features, dataframe_features)
#     153 # raise exception if any errors were found.
#     154 if len(err) > 0:
# --> 155     raise FeatureStoreException(
#     156         "Features are not compatible with Feature Group schema: "
#     157         + "".join(["\n - " + e for e in err])
#     158         + "\nNote that feature (or column) names are case insensitive and "
#     159         "spaces are automatically replaced with underscores."
#     160     )
#
# FeatureStoreException: Features are not compatible with Feature Group schema:
#  - pm25_1_days_before (type: 'float') does not exist in feature group.
#  - pm25_2_days_before (type: 'float') does not exist in feature group.
#  - pm25_3_days_before (type: 'float') does not exist in feature group.
#  - pm25_avg_3_days_before (type: 'float') does not exist in feature group.
# Note that feature (or column) names are case insensitive and spaces are automatically replaced with underscores.
